# %%
import numpy as np
import tensorflow as tf
import cv2

img = cv2.imread("Apple_healthy1.jpg.jpg")
img = cv2.resize(img,(128,128))
img = np.array(img,dtype="float32")
img = np.reshape(img , (1,128,128,3))

#Load the TFLite model and allocate tensors. 
interpreter = tf.lite.Interpreter(model_path="model.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.

input_details = interpreter.get_input_details()
output_details= interpreter.get_output_details()

# test the model on random input data.

input_shape = input_details[0]['shape']

print("*"*50 , input_details)

interpreter.invoke()
#The function 'get_tensor()' returns a copy of the tensor data.
#Use 'tensor()' in order to get a pointer to the tensor.

output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3648\3375019988.py in <module>
#       4
#       5 img = cv2.imread("Apple_healthy1.jpg.jpg")
# ----> 6 img = cv2.resize(img,(128,128))
#       7 img = np.array(img,dtype="float32")
#       8 img = np.reshape(img , (1,128,128,3))
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
import numpy as np
import tensorflow as tf
import cv2

# Load and preprocess the image
img = cv2.imread("algal_leaf_in_tea1.jpg")
img = cv2.resize(img, (128, 128))
img = np.array(img, dtype="float32")
img = np.reshape(img, (1, 128, 128, 3))

# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="model.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Set the input tensor value.
interpreter.set_tensor(input_details[0]['index'], img)

# Invoke the interpreter to perform inference.
interpreter.invoke()

# Get the output tensor value.
output_data = interpreter.get_tensor(output_details[0]['index'])

print("*" * 50, input_details)
print(output_data)

# %%
import numpy as np
import tensorflow as tf
import cv2
import os

# Specify the image file path
image_file = "Apple_healthy3.jpg"

# Check if the image file exists
if not os.path.exists(image_file):
    print(f"Error: Image file '{image_file}' not found.")
else:
    # Load and preprocess the image
    img = cv2.imread(image_file)
    
    if img is None:
        print(f"Error: Unable to load the image '{image_file}'. Check the image format and file path.")
    else:
        img = cv2.resize(img, (128, 128))
        img = np.array(img, dtype="float32")
        img = np.reshape(img, (1, 128, 128, 3))

        # Load the TFLite model and allocate tensors.
        interpreter = tf.lite.Interpreter(model_path="model.tflite")
        interpreter.allocate_tensors()

        # Get input and output tensors.
        input_details = interpreter.get_input_details()
        output_details = interpreter.get_output_details()

        # Set the input tensor value.
        interpreter.set_tensor(input_details[0]['index'], img)

        # Invoke the interpreter to perform inference.
        interpreter.invoke()

        # Get the output tensor value.
        output_data = interpreter.get_tensor(output_details[0]['index'])

        print("*" * 50, input_details)
        print(output_data)

# %%
import cv2

# Load an image
image = cv2.imread("Apple_healthy1.jpg")

# Check if the image is loaded successfully
if image is not None:
    # Specify the desired size (e.g., 100x100)
    desired_size = (100, 100)
    
    # Resize the image
    resized_image = cv2.resize(image, desired_size)
else:
    print("Failed to load the image.")

# %%
from keras.models import load_model
import tensorflow as tf

model = load_model("catdog.h5")


converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

print("model converted")

# Save the model.
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)

# %%
import numpy as np
import tensorflow as tf
import cv2

img = cv2.imread("Apple_healthy1.jpg.jpg")
img = cv2.resize(img, (128,128))
img = np.array(img, dtype="float32")
img = np.reshape(img, (1,128,128,3))


# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="model.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test the model on random input data.
input_shape = input_details[0]['shape']

print("*"*50, input_details)
interpreter.set_tensor(input_details[0]['index'], img)

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3648\2142270201.py in <module>
#       4
#       5 img = cv2.imread("Apple_healthy1.jpg.jpg")
# ----> 6 img = cv2.resize(img, (128,128))
#       7 img = np.array(img, dtype="float32")
#       8 img = np.reshape(img, (1,128,128,3))
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
